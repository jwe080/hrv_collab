# %%
# Import necessary libraries
import heartpy as hp
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import glob, os, gzip, json
from scipy.stats import zscore
import seaborn as sns
import neurokit2 as nk

# Set the base directory containing your data
# Change this to the directory where your data is stored
base_dir = '/data/MoodGroup/17M0060/bids/sourcedata'

# Use glob to find all .tsv.gz files that match the pattern in the base directory
# Adjust the pattern if your file naming convention is different
tsv_fns = glob.glob(os.path.join(base_dir,'*','*','func', '*rest*physio*.tsv.gz'))

# Initialize lists to store data
all_srate = []
all_bpm = []
all_dat = []
all_nope = []

# Loop through each found file
for idx, fn in enumerate(tsv_fns):
    base_fn = os.path.basename(fn)
    print(f"Processing file: {base_fn}")

    # If you sampling rate is not consistent read the corresponding JSON file to get the sampling frequency
    with open(fn.replace('tsv.gz', 'json'), 'r') as fid:
        json_dat = json.load(fid)

    #If the sampling rate is consistent then comment out the earlier lines and place the value
    srate = json_dat['SamplingFrequency']
    all_srate.append(srate)

    # Read the .tsv.gz file into a DataFrame
    dat = pd.read_csv(fn, compression='gzip', sep='\t', header=None, names=["ppg", "rsp", "trig"])

    try:
        # Process the PPG and RSP signals
        ppg_signals, ppg_info = nk.ppg_process(dat["ppg"], sampling_rate=srate)
        rsp_signals, rsp_info = nk.rsp_process(dat["rsp"][1:], sampling_rate=srate)

        # Extract interval-related measurements
        ppg_meas = nk.ppg_intervalrelated(ppg_signals)
        rsp_meas = nk.rsp_intervalrelated(rsp_signals)

        all_dat.append((ppg_signals, rsp_signals))

        # Parse the file name to get subject, session, and task information
        bids_bits = base_fn.split('_')

        # Handle the measurements
        tmp = [ii if isinstance(ii, np.float64) else ii[0] for idx, ii in enumerate(rsp_meas.values[0])]
        all_bpm.append(bids_bits[:-1] + [srate] + list(ppg_meas.values[0]) + tmp)

        # Print the results for the current file
        print(f"{idx}: {base_fn} - PPG Rate Mean: {ppg_meas['PPG_Rate_Mean'].values[0]}, RSP Rate Mean: {rsp_meas['RSP_Rate_Mean'].values[0]}")

    except Exception as e:
        print(f"{idx}: {base_fn} - Error: {e}")
        all_nope.append((fn, dat))

# Create a DataFrame of the collected measurements
# The columns are derived from the keys of the PPG and RSP measurement dictionaries
columns = ['sub', 'ses', 'task', 'run', 'echo', 'srate'] + list(ppg_meas.keys()) + list(rsp_meas.keys())
df = pd.DataFrame(all_bpm, columns=columns)

# Print the final DataFrame
print("Final DataFrame:")
print(df.head())
# Out:
# Processing file: sub-RD120_ses-20210511_task-rest_run-01_echo-01_physio.tsv.gz
# 0: sub-RD120_ses-20210511_task-rest_run-01_echo-01_physio.tsv.gz - PPG Rate Mean: 57.352979607965516, RSP Rate Mean: 7.4905882918865165
# Processing file: sub-RD120_ses-20210518_task-rest_run-101_echo-01_physio.tsv.gz
# 1: sub-RD120_ses-20210518_task-rest_run-101_echo-01_physio.tsv.gz - PPG Rate Mean: 58.260704658592104, RSP Rate Mean: 5.9658373029894225
# Processing file: sub-RD120_ses-20210518_task-rest_run-001_echo-01_physio.tsv.gz
# 2: sub-RD120_ses-20210518_task-rest_run-001_echo-01_physio.tsv.gz - PPG Rate Mean: 58.84331309498293, RSP Rate Mean: 5.907970364988176
# Processing file: sub-RD120_ses-20210518_task-rest_run-201_echo-01_physio.tsv.gz
# 3: sub-RD120_ses-20210518_task-rest_run-201_echo-01_physio.tsv.gz - PPG Rate Mean: 58.89674172591544, RSP Rate Mean: 6.517228742161686
# Processing file: sub-RD120_ses-20210518_task-rest_run-102_echo-01_physio.tsv.gz
# 4: sub-RD120_ses-20210518_task-rest_run-102_echo-01_physio.tsv.gz - PPG Rate Mean: 55.724787326596505, RSP Rate Mean: 5.781973476745673
# Processing file: sub-RD120_ses-20210525_task-rest_run-201_echo-01_physio.tsv.gz
# 5: sub-RD120_ses-20210525_task-rest_run-201_echo-01_physio.tsv.gz - PPG Rate Mean: 51.45487184073915, RSP Rate Mean: 4.9701145204539126
# Processing file: sub-RD120_ses-20210525_task-rest_run-101_echo-01_physio.tsv.gz
# 6: sub-RD120_ses-20210525_task-rest_run-101_echo-01_physio.tsv.gz - PPG Rate Mean: 49.64278308654453, RSP Rate Mean: 6.272051681247282
# Processing file: sub-RD120_ses-20210525_task-rest_run-001_echo-01_physio.tsv.gz
# 7: sub-RD120_ses-20210525_task-rest_run-001_echo-01_physio.tsv.gz - PPG Rate Mean: 51.673873369806536, RSP Rate Mean: 6.284614519541747
# Processing file: sub-RD120_ses-20210713_task-rest_run-01_echo-01_physio.tsv.gz
# 8: sub-RD120_ses-20210713_task-rest_run-01_echo-01_physio.tsv.gz - PPG Rate Mean: 50.78391769039162, RSP Rate Mean: 14.656996934431023
# Processing file: sub-RD120_ses-20210622_task-rest_run-01_echo-01_physio.tsv.gz
# 9: sub-RD120_ses-20210622_task-rest_run-01_echo-01_physio.tsv.gz - PPG Rate Mean: 60.46915827283836, RSP Rate Mean: 7.423257234255861
# Processing file: sub-RD120_ses-20210702_task-rest_run-01_echo-01_physio.tsv.gz
# 10: sub-RD120_ses-20210702_task-rest_run-01_echo-01_physio.tsv.gz - PPG Rate Mean: 63.83685255159966, RSP Rate Mean: 8.482598333617586
# Processing file: sub-RD122_ses-20210810_task-rest_run-101_echo-01_physio.tsv.gz
# 11: sub-RD122_ses-20210810_task-rest_run-101_echo-01_physio.tsv.gz - PPG Rate Mean: 59.15816478907347, RSP Rate Mean: 10.858021577126578
# Processing file: sub-RD122_ses-20210810_task-rest_run-201_echo-01_physio.tsv.gz
# 12: sub-RD122_ses-20210810_task-rest_run-201_echo-01_physio.tsv.gz - PPG Rate Mean: 61.016945436858975, RSP Rate Mean: 8.291448301039374
# Processing file: sub-RD122_ses-20210810_task-rest_run-001_echo-01_physio.tsv.gz
# 13: sub-RD122_ses-20210810_task-rest_run-001_echo-01_physio.tsv.gz - PPG Rate Mean: 59.192660807673484, RSP Rate Mean: 13.31728302576968
# Processing file: sub-RD122_ses-20210716_task-rest_run-01_echo-01_physio.tsv.gz
# 14: sub-RD122_ses-20210716_task-rest_run-01_echo-01_physio.tsv.gz - PPG Rate Mean: 62.66179067206873, RSP Rate Mean: 5.787596549114781
# Processing file: sub-RD122_ses-20210803_task-rest_run-001_echo-01_physio.tsv.gz
# 15: sub-RD122_ses-20210803_task-rest_run-001_echo-01_physio.tsv.gz - PPG Rate Mean: 59.7664462250882, RSP Rate Mean: 12.41077921064268
# Processing file: sub-RD122_ses-20210803_task-rest_run-101_echo-01_physio.tsv.gz
# 16: sub-RD122_ses-20210803_task-rest_run-101_echo-01_physio.tsv.gz - PPG Rate Mean: 64.81415415437999, RSP Rate Mean: 8.176194764396708
# Processing file: sub-RD122_ses-20210803_task-rest_run-201_echo-01_physio.tsv.gz
# 17: sub-RD122_ses-20210803_task-rest_run-201_echo-01_physio.tsv.gz - PPG Rate Mean: 82.76628521698684, RSP Rate Mean: 6.413335991646076
# Processing file: sub-RD122_ses-20210914_task-rest_run-01_echo-01_physio.tsv.gz
# 18: sub-RD122_ses-20210914_task-rest_run-01_echo-01_physio.tsv.gz - PPG Rate Mean: 66.98973129660538, RSP Rate Mean: 11.164155942032417
# Processing file: sub-RD109_ses-20190409_task-rest_run-001_echo-01_physio.tsv.gz
# 19: sub-RD109_ses-20190409_task-rest_run-001_echo-01_physio.tsv.gz - PPG Rate Mean: 62.273560239403665, RSP Rate Mean: 12.109639255714429
# Processing file: sub-RD109_ses-20190409_task-rest_run-101_echo-01_physio.tsv.gz
# 20: sub-RD109_ses-20190409_task-rest_run-101_echo-01_physio.tsv.gz - PPG Rate Mean: 62.93897816148527, RSP Rate Mean: 12.29686422161898
# Processing file: sub-RD109_ses-20190409_task-rest_run-201_echo-01_physio.tsv.gz
# 21: sub-RD109_ses-20190409_task-rest_run-201_echo-01_physio.tsv.gz - PPG Rate Mean: 62.190646070527826, RSP Rate Mean: 12.47501683916493
# Processing file: sub-RD109_ses-20190319_task-rest_run-02_echo-01_physio.tsv.gz
# 22: sub-RD109_ses-20190319_task-rest_run-02_echo-01_physio.tsv.gz - PPG Rate Mean: 61.73215640542747, RSP Rate Mean: 14.226718130993723
# Processing file: sub-RD109_ses-20190416_task-rest_run-202_echo-01_physio.tsv.gz
# 23: sub-RD109_ses-20190416_task-rest_run-202_echo-01_physio.tsv.gz - PPG Rate Mean: 64.61514696422547, RSP Rate Mean: 8.941865086331457
# Processing file: sub-RD109_ses-20190416_task-rest_run-001_echo-01_physio.tsv.gz
# 24: sub-RD109_ses-20190416_task-rest_run-001_echo-01_physio.tsv.gz - PPG Rate Mean: 60.32776497345534, RSP Rate Mean: 12.877315644114363
# Processing file: sub-RD109_ses-20190416_task-rest_run-101_echo-01_physio.tsv.gz
# 25: sub-RD109_ses-20190416_task-rest_run-101_echo-01_physio.tsv.gz - PPG Rate Mean: 61.3746241113959, RSP Rate Mean: 12.549920744502229
# Processing file: sub-RD109_ses-20190416_task-rest_run-201_echo-01_physio.tsv.gz
# 26: sub-RD109_ses-20190416_task-rest_run-201_echo-01_physio.tsv.gz - Error: SVD did not converge in Linear Least Squares
# Processing file: sub-RD119_ses-20210521_task-rest_run-01_echo-01_physio.tsv.gz
# /data/MoodGroup/code/miniconda3/envs/hrvanalysis/lib/python3.8/site-packages/neurokit2/signal/signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# /data/MoodGroup/code/miniconda3/envs/hrvanalysis/lib/python3.8/site-packages/neurokit2/rsp/rsp_symmetry.py:90: NeuroKitWarning: Not enough peaks and troughs (signal too short?) to compute symmetry, returning nan for symmetry.
#   warn(
# /data/MoodGroup/code/miniconda3/envs/hrvanalysis/lib/python3.8/site-packages/neurokit2/hrv/hrv_nonlinear.py:474: NeuroKitWarning: DFA_alpha2 related indices will not be calculated. The maximum duration of the windows provided for the long-term correlation is smaller than the minimum duration of windows. Refer to the `scale` argument in `nk.fractal_dfa()` for more information.
#   warn(
# 27: sub-RD119_ses-20210521_task-rest_run-01_echo-01_physio.tsv.gz - PPG Rate Mean: 64.40723505754946, RSP Rate Mean: 18.04605113784032
# Processing file: sub-RD119_ses-20210504_task-rest_run-201_echo-01_physio.tsv.gz
# 28: sub-RD119_ses-20210504_task-rest_run-201_echo-01_physio.tsv.gz - PPG Rate Mean: 58.33241505020791, RSP Rate Mean: 17.531278788500313
# Processing file: sub-RD119_ses-20210504_task-rest_run-101_echo-01_physio.tsv.gz
# 29: sub-RD119_ses-20210504_task-rest_run-101_echo-01_physio.tsv.gz - PPG Rate Mean: 56.629344699769945, RSP Rate Mean: 18.077315736004618
# Processing file: sub-RD119_ses-20210504_task-rest_run-001_echo-01_physio.tsv.gz
# 30: sub-RD119_ses-20210504_task-rest_run-001_echo-01_physio.tsv.gz - PPG Rate Mean: 56.06747038737779, RSP Rate Mean: 17.571213835240208
# Processing file: sub-RD119_ses-20210427_task-rest_run-101_echo-01_physio.tsv.gz
# 31: sub-RD119_ses-20210427_task-rest_run-101_echo-01_physio.tsv.gz - PPG Rate Mean: 77.73643049266545, RSP Rate Mean: 20.07505471434878
# Processing file: sub-RD119_ses-20210427_task-rest_run-201_echo-01_physio.tsv.gz
# 32: sub-RD119_ses-20210427_task-rest_run-201_echo-01_physio.tsv.gz - PPG Rate Mean: 101.72671973028652, RSP Rate Mean: 21.533306495429
# Processing file: sub-RD119_ses-20210427_task-rest_run-001_echo-01_physio.tsv.gz
# 33: sub-RD119_ses-20210427_task-rest_run-001_echo-01_physio.tsv.gz - PPG Rate Mean: 60.46520052724357, RSP Rate Mean: 17.067134762130678
# Processing file: sub-RD119_ses-20210608_task-rest_run-01_echo-01_physio.tsv.gz
# 34: sub-RD119_ses-20210608_task-rest_run-01_echo-01_physio.tsv.gz - PPG Rate Mean: 64.58242860857432, RSP Rate Mean: 17.96260295845896
# Processing file: sub-RD119_ses-20210406_task-rest_run-01_echo-01_physio.tsv.gz
# 35: sub-RD119_ses-20210406_task-rest_run-01_echo-01_physio.tsv.gz - PPG Rate Mean: 63.22037384103745, RSP Rate Mean: 20.134277785936213
# Processing file: sub-RD121_ses-20210813_task-rest_run-01_echo-01_physio.tsv.gz
# 36: sub-RD121_ses-20210813_task-rest_run-01_echo-01_physio.tsv.gz - PPG Rate Mean: 71.96449793591287, RSP Rate Mean: 18.17111632802721
# Processing file: sub-RD121_ses-20210817_task-rest_run-01_echo-01_physio.tsv.gz
# 37: sub-RD121_ses-20210817_task-rest_run-01_echo-01_physio.tsv.gz - PPG Rate Mean: 68.13637620325059, RSP Rate Mean: 17.469441464366486
# Processing file: sub-RD121_ses-20210730_task-rest_run-01_echo-01_physio.tsv.gz
# 38: sub-RD121_ses-20210730_task-rest_run-01_echo-01_physio.tsv.gz - PPG Rate Mean: 79.55395667180674, RSP Rate Mean: 18.68092223723042
# Processing file: sub-RD121_ses-20210615_task-rest_run-01_echo-01_physio.tsv.gz
# 39: sub-RD121_ses-20210615_task-rest_run-01_echo-01_physio.tsv.gz - PPG Rate Mean: 68.74865304580028, RSP Rate Mean: 18.67230252149434
# Processing file: sub-RD121_ses-20210706_task-rest_run-002_echo-01_physio.tsv.gz
# 40: sub-RD121_ses-20210706_task-rest_run-002_echo-01_physio.tsv.gz - PPG Rate Mean: 66.19098451109377, RSP Rate Mean: 16.600566669013716
# Processing file: sub-RD121_ses-20210706_task-rest_run-101_echo-01_physio.tsv.gz
# 41: sub-RD121_ses-20210706_task-rest_run-101_echo-01_physio.tsv.gz - PPG Rate Mean: 69.78533933106777, RSP Rate Mean: 13.918317538878846
# Processing file: sub-RD121_ses-20210706_task-rest_run-201_echo-01_physio.tsv.gz
# 42: sub-RD121_ses-20210706_task-rest_run-201_echo-01_physio.tsv.gz - PPG Rate Mean: 74.23941110358817, RSP Rate Mean: 13.625998355160286
# Processing file: sub-RD121_ses-20210713_task-rest_run-101_echo-01_physio.tsv.gz
# 43: sub-RD121_ses-20210713_task-rest_run-101_echo-01_physio.tsv.gz - PPG Rate Mean: 68.40317904147462, RSP Rate Mean: 15.504536850558466
# Processing file: sub-RD121_ses-20210713_task-rest_run-001_echo-01_physio.tsv.gz
# 44: sub-RD121_ses-20210713_task-rest_run-001_echo-01_physio.tsv.gz - PPG Rate Mean: 68.63064384793313, RSP Rate Mean: 16.100675094541597
# Processing file: sub-RD121_ses-20210713_task-rest_run-202_echo-01_physio.tsv.gz
# 45: sub-RD121_ses-20210713_task-rest_run-202_echo-01_physio.tsv.gz - PPG Rate Mean: 62.510740176523136, RSP Rate Mean: 15.373218267980407
# Processing file: sub-RD121_ses-20210723_task-rest_run-01_echo-01_physio.tsv.gz
# 46: sub-RD121_ses-20210723_task-rest_run-01_echo-01_physio.tsv.gz - PPG Rate Mean: 77.24994128263758, RSP Rate Mean: 19.302733085472433
# Processing file: sub-RD123_ses-20220628_task-rest_run-01_echo-01_physio.tsv.gz
# 47: sub-RD123_ses-20220628_task-rest_run-01_echo-01_physio.tsv.gz - PPG Rate Mean: 74.21677009263709, RSP Rate Mean: 12.603780145867576
# Processing file: sub-RD123_ses-20220506_task-rest_run-01_echo-01_physio.tsv.gz
# 48: sub-RD123_ses-20220506_task-rest_run-01_echo-01_physio.tsv.gz - PPG Rate Mean: 81.63273465808518, RSP Rate Mean: 9.278809029654502
# Processing file: sub-RD123_ses-20220517_task-rest_run-001_echo-01_physio.tsv.gz
# 49: sub-RD123_ses-20220517_task-rest_run-001_echo-01_physio.tsv.gz - PPG Rate Mean: 69.13313175538498, RSP Rate Mean: 10.340300687568172
# Processing file: sub-RD123_ses-20220517_task-rest_run-101_echo-01_physio.tsv.gz
# 50: sub-RD123_ses-20220517_task-rest_run-101_echo-01_physio.tsv.gz - PPG Rate Mean: 73.08255992662683, RSP Rate Mean: 8.983504587507909
# Processing file: sub-RD123_ses-20220517_task-rest_run-201_echo-01_physio.tsv.gz
# 51: sub-RD123_ses-20220517_task-rest_run-201_echo-01_physio.tsv.gz - PPG Rate Mean: 82.52441899377915, RSP Rate Mean: 8.687421258609389
# Processing file: sub-RD123_ses-20220510_task-rest_run-101_echo-01_physio.tsv.gz
# 52: sub-RD123_ses-20220510_task-rest_run-101_echo-01_physio.tsv.gz - PPG Rate Mean: 70.89805684758142, RSP Rate Mean: 9.696476928165117
# Processing file: sub-RD123_ses-20220510_task-rest_run-002_echo-01_physio.tsv.gz
# 53: sub-RD123_ses-20220510_task-rest_run-002_echo-01_physio.tsv.gz - PPG Rate Mean: 71.28119594771665, RSP Rate Mean: 11.423559931411573
# Processing file: sub-RD123_ses-20220510_task-rest_run-201_echo-01_physio.tsv.gz
# 54: sub-RD123_ses-20220510_task-rest_run-201_echo-01_physio.tsv.gz - PPG Rate Mean: 71.51243937535925, RSP Rate Mean: 10.037074910163094
# Processing file: sub-RD115_ses-20191119_task-rest_run-01_echo-01_physio.tsv.gz
# 55: sub-RD115_ses-20191119_task-rest_run-01_echo-01_physio.tsv.gz - PPG Rate Mean: 69.20042752866718, RSP Rate Mean: 14.159626665297045
# Processing file: sub-RD115_ses-20191203_task-rest_run-001_echo-01_physio.tsv.gz
# 56: sub-RD115_ses-20191203_task-rest_run-001_echo-01_physio.tsv.gz - PPG Rate Mean: 64.95613375583662, RSP Rate Mean: 15.334529444394013
# Processing file: sub-RD115_ses-20191203_task-rest_run-201_echo-01_physio.tsv.gz
# 57: sub-RD115_ses-20191203_task-rest_run-201_echo-01_physio.tsv.gz - PPG Rate Mean: 92.94842413160501, RSP Rate Mean: 7.801127110994389
# Processing file: sub-RD115_ses-20191203_task-rest_run-101_echo-01_physio.tsv.gz
# /data/MoodGroup/code/miniconda3/envs/hrvanalysis/lib/python3.8/site-packages/neurokit2/signal/signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# /data/MoodGroup/code/miniconda3/envs/hrvanalysis/lib/python3.8/site-packages/neurokit2/rsp/rsp_symmetry.py:90: NeuroKitWarning: Not enough peaks and troughs (signal too short?) to compute symmetry, returning nan for symmetry.
#   warn(
# /data/MoodGroup/code/miniconda3/envs/hrvanalysis/lib/python3.8/site-packages/neurokit2/hrv/hrv_nonlinear.py:474: NeuroKitWarning: DFA_alpha2 related indices will not be calculated. The maximum duration of the windows provided for the long-term correlation is smaller than the minimum duration of windows. Refer to the `scale` argument in `nk.fractal_dfa()` for more information.
#   warn(
# /data/MoodGroup/code/miniconda3/envs/hrvanalysis/lib/python3.8/site-packages/neurokit2/rsp/rsp_intervalrelated.py:93: RuntimeWarning: Mean of empty slice
#   output["RSP_Rate_Mean"] = np.nanmean(data["RSP_Rate"].values)
# /data/MoodGroup/code/miniconda3/envs/hrvanalysis/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3372: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /data/MoodGroup/code/miniconda3/envs/hrvanalysis/lib/python3.8/site-packages/neurokit2/rsp/rsp_rrv.py:140: RuntimeWarning: Mean of empty slice
#   out["MeanBB"] = np.nanmean(bbi)
# /data/MoodGroup/code/miniconda3/envs/hrvanalysis/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1664: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /data/MoodGroup/code/miniconda3/envs/hrvanalysis/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /data/MoodGroup/code/miniconda3/envs/hrvanalysis/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# 58: sub-RD115_ses-20191203_task-rest_run-101_echo-01_physio.tsv.gz - Error: ('NeuroKit error: complexity_embedding(): dimension * delay should be lower than', ' the length of the signal.')
# Processing file: sub-RD115_ses-20191203_task-rest_run-102_echo-01_physio.tsv.gz
# 59: sub-RD115_ses-20191203_task-rest_run-102_echo-01_physio.tsv.gz - PPG Rate Mean: 74.62224300129851, RSP Rate Mean: 9.10491410672664
# Processing file: sub-RD115_ses-20191126_task-rest_run-201_echo-01_physio.tsv.gz
# 60: sub-RD115_ses-20191126_task-rest_run-201_echo-01_physio.tsv.gz - PPG Rate Mean: 80.34885915103396, RSP Rate Mean: 14.894524825814146
# Processing file: sub-RD115_ses-20191126_task-rest_run-102_echo-01_physio.tsv.gz
# 61: sub-RD115_ses-20191126_task-rest_run-102_echo-01_physio.tsv.gz - PPG Rate Mean: 89.63380047836007, RSP Rate Mean: 8.499447240905097
# Processing file: sub-RD115_ses-20191126_task-rest_run-001_echo-01_physio.tsv.gz
# 62: sub-RD115_ses-20191126_task-rest_run-001_echo-01_physio.tsv.gz - PPG Rate Mean: 82.839872208777, RSP Rate Mean: 12.638112325280094
# Processing file: sub-RD115_ses-20191126_task-rest_run-101_echo-01_physio.tsv.gz
# 63: sub-RD115_ses-20191126_task-rest_run-101_echo-01_physio.tsv.gz - PPG Rate Mean: 82.04119992526802, RSP Rate Mean: 7.233134409165778
# Processing file: sub-RD115_ses-20200128_task-rest_run-01_echo-01_physio.tsv.gz
# 64: sub-RD115_ses-20200128_task-rest_run-01_echo-01_physio.tsv.gz - PPG Rate Mean: 79.83291630815808, RSP Rate Mean: 9.66378797863284
# Processing file: sub-RD110_ses-20190604_task-rest_run-101_echo-01_physio.tsv.gz
# 65: sub-RD110_ses-20190604_task-rest_run-101_echo-01_physio.tsv.gz - PPG Rate Mean: 48.87753043687962, RSP Rate Mean: 12.396147774555605
# Processing file: sub-RD110_ses-20190604_task-rest_run-001_echo-01_physio.tsv.gz
# 66: sub-RD110_ses-20190604_task-rest_run-001_echo-01_physio.tsv.gz - PPG Rate Mean: 59.212427942807196, RSP Rate Mean: 12.223439534588602
# Processing file: sub-RD110_ses-20190604_task-rest_run-201_echo-01_physio.tsv.gz
# 67: sub-RD110_ses-20190604_task-rest_run-201_echo-01_physio.tsv.gz - PPG Rate Mean: 67.46242643694849, RSP Rate Mean: 15.41596441991896
# Processing file: sub-RD110_ses-20190528_task-rest_run-001_echo-01_physio.tsv.gz
# 68: sub-RD110_ses-20190528_task-rest_run-001_echo-01_physio.tsv.gz - PPG Rate Mean: 57.90435955660481, RSP Rate Mean: 13.410216780803532
# Processing file: sub-RD110_ses-20190528_task-rest_run-101_echo-01_physio.tsv.gz
# 69: sub-RD110_ses-20190528_task-rest_run-101_echo-01_physio.tsv.gz - PPG Rate Mean: 61.85506962440196, RSP Rate Mean: 14.434606349035436
# Processing file: sub-RD110_ses-20190528_task-rest_run-102_echo-01_physio.tsv.gz
# 70: sub-RD110_ses-20190528_task-rest_run-102_echo-01_physio.tsv.gz - PPG Rate Mean: 72.96683013855203, RSP Rate Mean: 16.6424303468429
# Processing file: sub-RD110_ses-20190528_task-rest_run-201_echo-01_physio.tsv.gz
# 71: sub-RD110_ses-20190528_task-rest_run-201_echo-01_physio.tsv.gz - PPG Rate Mean: 95.61356226825477, RSP Rate Mean: 19.20364485662369
# Processing file: sub-RD110_ses-20190507_task-rest_run-02_echo-01_physio.tsv.gz
# 72: sub-RD110_ses-20190507_task-rest_run-02_echo-01_physio.tsv.gz - PPG Rate Mean: 60.82921092700586, RSP Rate Mean: 16.948920979608584
# Processing file: sub-RD127_ses-20240130_task-rest_run-201_echo-01_physio.tsv.gz
# 73: sub-RD127_ses-20240130_task-rest_run-201_echo-01_physio.tsv.gz - PPG Rate Mean: 57.84625272760258, RSP Rate Mean: 10.78317236771373
# Processing file: sub-RD127_ses-20240130_task-rest_run-101_echo-01_physio.tsv.gz
# 74: sub-RD127_ses-20240130_task-rest_run-101_echo-01_physio.tsv.gz - PPG Rate Mean: 60.30957271123192, RSP Rate Mean: 10.499309471450088
# Processing file: sub-RD127_ses-20240130_task-rest_run-001_echo-01_physio.tsv.gz
# 75: sub-RD127_ses-20240130_task-rest_run-001_echo-01_physio.tsv.gz - PPG Rate Mean: 60.4638503512817, RSP Rate Mean: 11.390711335476206
# Processing file: sub-RD127_ses-20240206_task-rest_run-102_echo-01_physio.tsv.gz
# /data/MoodGroup/code/miniconda3/envs/hrvanalysis/lib/python3.8/site-packages/neurokit2/signal/signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# /data/MoodGroup/code/miniconda3/envs/hrvanalysis/lib/python3.8/site-packages/neurokit2/rsp/rsp_symmetry.py:90: NeuroKitWarning: Not enough peaks and troughs (signal too short?) to compute symmetry, returning nan for symmetry.
#   warn(
# /data/MoodGroup/code/miniconda3/envs/hrvanalysis/lib/python3.8/site-packages/neurokit2/hrv/hrv_nonlinear.py:474: NeuroKitWarning: DFA_alpha2 related indices will not be calculated. The maximum duration of the windows provided for the long-term correlation is smaller than the minimum duration of windows. Refer to the `scale` argument in `nk.fractal_dfa()` for more information.
#   warn(
# /data/MoodGroup/code/miniconda3/envs/hrvanalysis/lib/python3.8/site-packages/neurokit2/rsp/rsp_intervalrelated.py:93: RuntimeWarning: Mean of empty slice
#   output["RSP_Rate_Mean"] = np.nanmean(data["RSP_Rate"].values)
# /data/MoodGroup/code/miniconda3/envs/hrvanalysis/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3372: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /data/MoodGroup/code/miniconda3/envs/hrvanalysis/lib/python3.8/site-packages/neurokit2/rsp/rsp_rrv.py:140: RuntimeWarning: Mean of empty slice
#   out["MeanBB"] = np.nanmean(bbi)
# /data/MoodGroup/code/miniconda3/envs/hrvanalysis/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1664: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /data/MoodGroup/code/miniconda3/envs/hrvanalysis/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /data/MoodGroup/code/miniconda3/envs/hrvanalysis/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# 76: sub-RD127_ses-20240206_task-rest_run-102_echo-01_physio.tsv.gz - Error: ('NeuroKit error: complexity_embedding(): dimension * delay should be lower than', ' the length of the signal.')
# Processing file: sub-RD127_ses-20240206_task-rest_run-201_echo-01_physio.tsv.gz
# 77: sub-RD127_ses-20240206_task-rest_run-201_echo-01_physio.tsv.gz - PPG Rate Mean: 67.06835009776583, RSP Rate Mean: 9.086695456776642
# Processing file: sub-RD127_ses-20240206_task-rest_run-103_echo-01_physio.tsv.gz
# /data/MoodGroup/code/miniconda3/envs/hrvanalysis/lib/python3.8/site-packages/neurokit2/hrv/hrv_nonlinear.py:474: NeuroKitWarning: DFA_alpha2 related indices will not be calculated. The maximum duration of the windows provided for the long-term correlation is smaller than the minimum duration of windows. Refer to the `scale` argument in `nk.fractal_dfa()` for more information.
#   warn(
# 78: sub-RD127_ses-20240206_task-rest_run-103_echo-01_physio.tsv.gz - PPG Rate Mean: 62.39555322521193, RSP Rate Mean: 10.454000914071646
# Processing file: sub-RD127_ses-20240206_task-rest_run-104_echo-01_physio.tsv.gz
# 79: sub-RD127_ses-20240206_task-rest_run-104_echo-01_physio.tsv.gz - PPG Rate Mean: 65.90410096361126, RSP Rate Mean: 10.37275970941531
# Processing file: sub-RD127_ses-20240206_task-rest_run-001_echo-01_physio.tsv.gz
# 80: sub-RD127_ses-20240206_task-rest_run-001_echo-01_physio.tsv.gz - PPG Rate Mean: 63.36704078976148, RSP Rate Mean: 9.84817000140879
# Processing file: sub-RD127_ses-20240206_task-rest_run-101_echo-01_physio.tsv.gz
# 81: sub-RD127_ses-20240206_task-rest_run-101_echo-01_physio.tsv.gz - PPG Rate Mean: 62.591739031535134, RSP Rate Mean: 10.170358054005101
# Processing file: sub-RD127_ses-20240123_task-rest_run-01_echo-01_physio.tsv.gz
# 82: sub-RD127_ses-20240123_task-rest_run-01_echo-01_physio.tsv.gz - PPG Rate Mean: 63.41625519442403, RSP Rate Mean: 9.650725474139769
# Processing file: sub-RD111_ses-20190604_task-rest_run-01_echo-01_physio.tsv.gz
# 83: sub-RD111_ses-20190604_task-rest_run-01_echo-01_physio.tsv.gz - PPG Rate Mean: 62.872071197375256, RSP Rate Mean: 14.153947267473482
# Processing file: sub-RD111_ses-20190702_task-rest_run-102_echo-01_physio.tsv.gz
# 84: sub-RD111_ses-20190702_task-rest_run-102_echo-01_physio.tsv.gz - PPG Rate Mean: 60.5297248324809, RSP Rate Mean: 11.350141480138662
# Processing file: sub-RD111_ses-20190702_task-rest_run-201_echo-01_physio.tsv.gz
# 85: sub-RD111_ses-20190702_task-rest_run-201_echo-01_physio.tsv.gz - PPG Rate Mean: 60.31401293999005, RSP Rate Mean: 12.691472466443678
# Processing file: sub-RD111_ses-20190702_task-rest_run-101_echo-01_physio.tsv.gz
# /data/MoodGroup/code/miniconda3/envs/hrvanalysis/lib/python3.8/site-packages/neurokit2/hrv/hrv_nonlinear.py:474: NeuroKitWarning: DFA_alpha2 related indices will not be calculated. The maximum duration of the windows provided for the long-term correlation is smaller than the minimum duration of windows. Refer to the `scale` argument in `nk.fractal_dfa()` for more information.
#   warn(
# 86: sub-RD111_ses-20190702_task-rest_run-101_echo-01_physio.tsv.gz - PPG Rate Mean: 64.92600307980503, RSP Rate Mean: 12.750408301020242
# Processing file: sub-RD111_ses-20190702_task-rest_run-001_echo-01_physio.tsv.gz
# 87: sub-RD111_ses-20190702_task-rest_run-001_echo-01_physio.tsv.gz - PPG Rate Mean: 56.134111845665466, RSP Rate Mean: 12.561980348874185
# Processing file: sub-RD111_ses-20190709_task-rest_run-001_echo-01_physio.tsv.gz
# /data/MoodGroup/code/miniconda3/envs/hrvanalysis/lib/python3.8/site-packages/neurokit2/signal/signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# /data/MoodGroup/code/miniconda3/envs/hrvanalysis/lib/python3.8/site-packages/neurokit2/rsp/rsp_symmetry.py:90: NeuroKitWarning: Not enough peaks and troughs (signal too short?) to compute symmetry, returning nan for symmetry.
#   warn(
# /data/MoodGroup/code/miniconda3/envs/hrvanalysis/lib/python3.8/site-packages/neurokit2/hrv/hrv_nonlinear.py:474: NeuroKitWarning: DFA_alpha2 related indices will not be calculated. The maximum duration of the windows provided for the long-term correlation is smaller than the minimum duration of windows. Refer to the `scale` argument in `nk.fractal_dfa()` for more information.
#   warn(
# 88: sub-RD111_ses-20190709_task-rest_run-001_echo-01_physio.tsv.gz - Error: SVD did not converge in Linear Least Squares
# Processing file: sub-RD111_ses-20190709_task-rest_run-201_echo-01_physio.tsv.gz
# 89: sub-RD111_ses-20190709_task-rest_run-201_echo-01_physio.tsv.gz - PPG Rate Mean: 53.23756598284074, RSP Rate Mean: 10.311567941385968
# Processing file: sub-RD111_ses-20190709_task-rest_run-002_echo-01_physio.tsv.gz
# 90: sub-RD111_ses-20190709_task-rest_run-002_echo-01_physio.tsv.gz - PPG Rate Mean: 54.19497132217097, RSP Rate Mean: 10.922716618357423
# Processing file: sub-RD111_ses-20190709_task-rest_run-101_echo-01_physio.tsv.gz
# 91: sub-RD111_ses-20190709_task-rest_run-101_echo-01_physio.tsv.gz - PPG Rate Mean: 52.28505149771759, RSP Rate Mean: 10.844158179726085
# Processing file: sub-RD111_ses-20190813_task-rest_run-02_echo-01_physio.tsv.gz
# 92: sub-RD111_ses-20190813_task-rest_run-02_echo-01_physio.tsv.gz - PPG Rate Mean: 60.01125268429182, RSP Rate Mean: 12.63786132798996
# Processing file: sub-RD126_ses-20230516_task-rest_run-01_echo-01_physio.tsv.gz
# 93: sub-RD126_ses-20230516_task-rest_run-01_echo-01_physio.tsv.gz - PPG Rate Mean: 62.65587162504841, RSP Rate Mean: 17.964603355048947
# Processing file: sub-RD126_ses-20230530_task-rest_run-001_echo-01_physio.tsv.gz
# 94: sub-RD126_ses-20230530_task-rest_run-001_echo-01_physio.tsv.gz - PPG Rate Mean: 52.74783490183778, RSP Rate Mean: 15.196051545977447
# Processing file: sub-RD126_ses-20230530_task-rest_run-201_echo-01_physio.tsv.gz
# 95: sub-RD126_ses-20230530_task-rest_run-201_echo-01_physio.tsv.gz - PPG Rate Mean: 54.978005959188415, RSP Rate Mean: 12.972663456044316
# Processing file: sub-RD126_ses-20230530_task-rest_run-101_echo-01_physio.tsv.gz
# 96: sub-RD126_ses-20230530_task-rest_run-101_echo-01_physio.tsv.gz - PPG Rate Mean: 52.74109334053668, RSP Rate Mean: 10.788948236184623
# Processing file: sub-RD126_ses-20230523_task-rest_run-01_echo-01_physio.tsv.gz
# 97: sub-RD126_ses-20230523_task-rest_run-01_echo-01_physio.tsv.gz - PPG Rate Mean: 53.97172654377707, RSP Rate Mean: 14.845485665541384
# Processing file: sub-RD126_ses-20230523_task-rest_run-101_echo-01_physio.tsv.gz
# 98: sub-RD126_ses-20230523_task-rest_run-101_echo-01_physio.tsv.gz - PPG Rate Mean: 56.147051254952274, RSP Rate Mean: 17.940101478985888
# Processing file: sub-RD126_ses-20230523_task-rest_run-201_echo-01_physio.tsv.gz
# 99: sub-RD126_ses-20230523_task-rest_run-201_echo-01_physio.tsv.gz - PPG Rate Mean: 57.797990090461326, RSP Rate Mean: 17.39589669986461
# Processing file: sub-RD126_ses-20230725_task-rest_run-01_echo-01_physio.tsv.gz
# 100: sub-RD126_ses-20230725_task-rest_run-01_echo-01_physio.tsv.gz - PPG Rate Mean: 59.17781152609672, RSP Rate Mean: 15.142894932615485
# Processing file: sub-RD114_ses-20191112_task-rest_run-01_echo-01_physio.tsv.gz
# 101: sub-RD114_ses-20191112_task-rest_run-01_echo-01_physio.tsv.gz - PPG Rate Mean: 57.856699226493845, RSP Rate Mean: 15.851649993244077
# Processing file: sub-RD114_ses-20191015_task-rest_run-101_echo-01_physio.tsv.gz
# 102: sub-RD114_ses-20191015_task-rest_run-101_echo-01_physio.tsv.gz - PPG Rate Mean: 63.700904574388446, RSP Rate Mean: 16.472301257640932
# Processing file: sub-RD114_ses-20191015_task-rest_run-001_echo-01_physio.tsv.gz
# 103: sub-RD114_ses-20191015_task-rest_run-001_echo-01_physio.tsv.gz - PPG Rate Mean: 63.23481988459265, RSP Rate Mean: 17.623058506731322
# Processing file: sub-RD114_ses-20191015_task-rest_run-201_echo-01_physio.tsv.gz
# 104: sub-RD114_ses-20191015_task-rest_run-201_echo-01_physio.tsv.gz - PPG Rate Mean: 58.25534877619704, RSP Rate Mean: 14.633574556215358
# Processing file: sub-RD114_ses-20191015_task-rest_run-102_echo-01_physio.tsv.gz
# 105: sub-RD114_ses-20191015_task-rest_run-102_echo-01_physio.tsv.gz - PPG Rate Mean: 59.94233966117935, RSP Rate Mean: 15.11995795913091
# Processing file: sub-RD114_ses-20191008_task-rest_run-01_echo-01_physio.tsv.gz
# 106: sub-RD114_ses-20191008_task-rest_run-01_echo-01_physio.tsv.gz - PPG Rate Mean: 58.17420511548851, RSP Rate Mean: 15.9988934640756
# Processing file: sub-RD114_ses-20191022_task-rest_run-201_echo-01_physio.tsv.gz
# 107: sub-RD114_ses-20191022_task-rest_run-201_echo-01_physio.tsv.gz - PPG Rate Mean: 68.146118233178, RSP Rate Mean: 18.474262361413366
# Processing file: sub-RD114_ses-20191022_task-rest_run-001_echo-01_physio.tsv.gz
# 108: sub-RD114_ses-20191022_task-rest_run-001_echo-01_physio.tsv.gz - PPG Rate Mean: 54.165524135214184, RSP Rate Mean: 16.399258014719624
# Processing file: sub-RD114_ses-20191022_task-rest_run-101_echo-01_physio.tsv.gz
# 109: sub-RD114_ses-20191022_task-rest_run-101_echo-01_physio.tsv.gz - PPG Rate Mean: 54.76121174086942, RSP Rate Mean: 16.24501699097036
# Processing file: sub-RD107_ses-20180821_task-rest_run-001_echo-01_physio.tsv.gz
# 110: sub-RD107_ses-20180821_task-rest_run-001_echo-01_physio.tsv.gz - PPG Rate Mean: 64.42756869489034, RSP Rate Mean: 13.27661874426455
# Processing file: sub-RD107_ses-20180821_task-rest_run-101_echo-01_physio.tsv.gz
# 111: sub-RD107_ses-20180821_task-rest_run-101_echo-01_physio.tsv.gz - PPG Rate Mean: 73.89486451629406, RSP Rate Mean: 13.481061894256538
# Processing file: sub-RD107_ses-20180821_task-rest_run-201_echo-01_physio.tsv.gz
# 112: sub-RD107_ses-20180821_task-rest_run-201_echo-01_physio.tsv.gz - PPG Rate Mean: 66.7763802364503, RSP Rate Mean: 13.06792202999314
# Processing file: sub-RD107_ses-20180814_task-rest_run-01_echo-01_physio.tsv.gz
# 113: sub-RD107_ses-20180814_task-rest_run-01_echo-01_physio.tsv.gz - PPG Rate Mean: 60.73050016607699, RSP Rate Mean: 13.240132145105877
# Processing file: sub-RD128_ses-20240528_task-rest_run-001_echo-01_physio.tsv.gz
# 114: sub-RD128_ses-20240528_task-rest_run-001_echo-01_physio.tsv.gz - PPG Rate Mean: 76.38280821830273, RSP Rate Mean: 10.899318732481882
# Processing file: sub-RD128_ses-20240528_task-rest_run-101_echo-01_physio.tsv.gz
# 115: sub-RD128_ses-20240528_task-rest_run-101_echo-01_physio.tsv.gz - PPG Rate Mean: 79.36910845731765, RSP Rate Mean: 9.200678322028986
# Processing file: sub-RD128_ses-20240528_task-rest_run-201_echo-01_physio.tsv.gz
# 116: sub-RD128_ses-20240528_task-rest_run-201_echo-01_physio.tsv.gz - PPG Rate Mean: 87.17769210066956, RSP Rate Mean: 8.082848220289456
# Processing file: sub-RD128_ses-20240528_task-rest_run-101_None_physio.tsv.gz
# 117: sub-RD128_ses-20240528_task-rest_run-101_None_physio.tsv.gz - PPG Rate Mean: 79.36910845731765, RSP Rate Mean: 9.200678322028986
# Processing file: sub-RD128_ses-20240528_task-rest_run-201_None_physio.tsv.gz
# 118: sub-RD128_ses-20240528_task-rest_run-201_None_physio.tsv.gz - PPG Rate Mean: 87.17769210066956, RSP Rate Mean: 8.082848220289456
# Processing file: sub-RD128_ses-20240528_task-rest_run-001_None_physio.tsv.gz
# 119: sub-RD128_ses-20240528_task-rest_run-001_None_physio.tsv.gz - PPG Rate Mean: 76.38280821830273, RSP Rate Mean: 10.899318732481882
# Processing file: sub-RD128_ses-20240521_task-rest_run-01_echo-01_physio.tsv.gz
# 120: sub-RD128_ses-20240521_task-rest_run-01_echo-01_physio.tsv.gz - PPG Rate Mean: 73.71032045757867, RSP Rate Mean: 10.94665905235494
# Processing file: sub-RD128_ses-20240521_task-rest_run-01_echo-01_physio.tsv.gz
# 121: sub-RD128_ses-20240521_task-rest_run-01_echo-01_physio.tsv.gz - PPG Rate Mean: 73.71032045757867, RSP Rate Mean: 10.94665905235494
# Processing file: sub-RD128_ses-20240604_task-rest_run-001_echo-01_physio.tsv.gz
# 122: sub-RD128_ses-20240604_task-rest_run-001_echo-01_physio.tsv.gz - PPG Rate Mean: 74.82978866684581, RSP Rate Mean: 10.898400367531167
# Processing file: sub-RD128_ses-20240604_task-rest_run-201_echo-01_physio.tsv.gz
# 123: sub-RD128_ses-20240604_task-rest_run-201_echo-01_physio.tsv.gz - PPG Rate Mean: 71.41446182333227, RSP Rate Mean: 9.6799141506273
# Processing file: sub-RD128_ses-20240604_task-rest_run-101_echo-01_physio.tsv.gz
# 124: sub-RD128_ses-20240604_task-rest_run-101_echo-01_physio.tsv.gz - PPG Rate Mean: 72.69265766093802, RSP Rate Mean: 9.444074982687455
# Processing file: sub-RD101_ses-20170718_task-rest_run-101_echo-01_physio.tsv.gz
# 125: sub-RD101_ses-20170718_task-rest_run-101_echo-01_physio.tsv.gz - PPG Rate Mean: 52.82114665230864, RSP Rate Mean: 17.20785879956134
# Processing file: sub-RD101_ses-20170718_task-rest_run-001_echo-01_physio.tsv.gz
# 126: sub-RD101_ses-20170718_task-rest_run-001_echo-01_physio.tsv.gz - PPG Rate Mean: 51.63430911876491, RSP Rate Mean: 17.11795383981119
# Processing file: sub-RD101_ses-20170718_task-rest_run-201_echo-01_physio.tsv.gz
# 127: sub-RD101_ses-20170718_task-rest_run-201_echo-01_physio.tsv.gz - PPG Rate Mean: 53.1942143827571, RSP Rate Mean: 18.527970908281876
# Processing file: sub-RD101_ses-20170829_task-rest_run-01_echo-01_physio.tsv.gz
# 128: sub-RD101_ses-20170829_task-rest_run-01_echo-01_physio.tsv.gz - PPG Rate Mean: 58.16691786213409, RSP Rate Mean: 18.337419961003995
# Processing file: sub-RD101_ses-20170725_task-rest_run-001_echo-01_physio.tsv.gz
# 129: sub-RD101_ses-20170725_task-rest_run-001_echo-01_physio.tsv.gz - PPG Rate Mean: 55.660481059380764, RSP Rate Mean: 17.00939259954707
# Processing file: sub-RD101_ses-20170725_task-rest_run-102_echo-01_physio.tsv.gz
# 130: sub-RD101_ses-20170725_task-rest_run-102_echo-01_physio.tsv.gz - PPG Rate Mean: 62.50829681630087, RSP Rate Mean: 16.81873519852835
# Processing file: sub-RD101_ses-20170725_task-rest_run-101_echo-01_physio.tsv.gz
# 131: sub-RD101_ses-20170725_task-rest_run-101_echo-01_physio.tsv.gz - PPG Rate Mean: 57.321105531314636, RSP Rate Mean: 16.69908962312805
# Processing file: sub-RD101_ses-20170725_task-rest_run-201_echo-01_physio.tsv.gz
# 132: sub-RD101_ses-20170725_task-rest_run-201_echo-01_physio.tsv.gz - PPG Rate Mean: 71.9275389337417, RSP Rate Mean: 19.00461715889681
# Processing file: sub-RD124_ses-20230321_task-rest_run-201_echo-01_physio.tsv.gz
# 133: sub-RD124_ses-20230321_task-rest_run-201_echo-01_physio.tsv.gz - Error: index 0 is out of bounds for axis 0 with size 0
# Processing file: sub-RD124_ses-20230321_task-rest_run-202_echo-01_physio.tsv.gz
# 134: sub-RD124_ses-20230321_task-rest_run-202_echo-01_physio.tsv.gz - PPG Rate Mean: 61.52036230934966, RSP Rate Mean: 6.589474941544204
# Processing file: sub-RD124_ses-20230321_task-rest_run-001_echo-01_physio.tsv.gz
# 135: sub-RD124_ses-20230321_task-rest_run-001_echo-01_physio.tsv.gz - Error: index 0 is out of bounds for axis 0 with size 0
# Processing file: sub-RD124_ses-20230321_task-rest_run-101_echo-01_physio.tsv.gz
# /data/MoodGroup/code/miniconda3/envs/hrvanalysis/lib/python3.8/site-packages/neurokit2/signal/signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# 136: sub-RD124_ses-20230321_task-rest_run-101_echo-01_physio.tsv.gz - PPG Rate Mean: 53.397669411067056, RSP Rate Mean: 11.570734281609889
# Processing file: sub-RD124_ses-20230328_task-rest_run-102_echo-01_physio.tsv.gz
# 137: sub-RD124_ses-20230328_task-rest_run-102_echo-01_physio.tsv.gz - PPG Rate Mean: 56.06424175171267, RSP Rate Mean: 7.134316081400716
# Processing file: sub-RD124_ses-20230328_task-rest_run-101_echo-01_physio.tsv.gz
# 138: sub-RD124_ses-20230328_task-rest_run-101_echo-01_physio.tsv.gz - PPG Rate Mean: 51.72393659870025, RSP Rate Mean: 7.194195087393667
# Processing file: sub-RD124_ses-20230328_task-rest_run-001_echo-01_physio.tsv.gz
# 139: sub-RD124_ses-20230328_task-rest_run-001_echo-01_physio.tsv.gz - PPG Rate Mean: 52.43354312294168, RSP Rate Mean: 9.795263988532886
# Processing file: sub-RD124_ses-20230328_task-rest_run-201_echo-01_physio.tsv.gz
# 140: sub-RD124_ses-20230328_task-rest_run-201_echo-01_physio.tsv.gz - PPG Rate Mean: 59.1665316069593, RSP Rate Mean: 5.2390185974368935
# Processing file: sub-RD105_ses-20180227_task-rest_run-02_echo-01_physio.tsv.gz
# 141: sub-RD105_ses-20180227_task-rest_run-02_echo-01_physio.tsv.gz - PPG Rate Mean: 64.34961424638323, RSP Rate Mean: 13.934602823595183
# Processing file: sub-RD105_ses-20180501_task-rest_run-02_echo-01_physio.tsv.gz
# 142: sub-RD105_ses-20180501_task-rest_run-02_echo-01_physio.tsv.gz - PPG Rate Mean: 64.18138143873061, RSP Rate Mean: 14.878086823755583
# Processing file: sub-RD105_ses-20180313_task-rest_run-001_echo-01_physio.tsv.gz
# 143: sub-RD105_ses-20180313_task-rest_run-001_echo-01_physio.tsv.gz - PPG Rate Mean: 61.03649655603894, RSP Rate Mean: 16.003684098637727
# Processing file: sub-RD105_ses-20180313_task-rest_run-201_echo-01_physio.tsv.gz
# 144: sub-RD105_ses-20180313_task-rest_run-201_echo-01_physio.tsv.gz - PPG Rate Mean: 58.2638045545146, RSP Rate Mean: 13.928578251999959
# Processing file: sub-RD105_ses-20180313_task-rest_run-101_echo-01_physio.tsv.gz
# 145: sub-RD105_ses-20180313_task-rest_run-101_echo-01_physio.tsv.gz - PPG Rate Mean: 58.219078284280414, RSP Rate Mean: 14.805966601806809
# Processing file: sub-RD105_ses-20180306_task-rest_run-001_echo-01_physio.tsv.gz
# 146: sub-RD105_ses-20180306_task-rest_run-001_echo-01_physio.tsv.gz - PPG Rate Mean: 61.837206316226116, RSP Rate Mean: 16.538617781501248
# Processing file: sub-RD105_ses-20180306_task-rest_run-101_echo-01_physio.tsv.gz
# 147: sub-RD105_ses-20180306_task-rest_run-101_echo-01_physio.tsv.gz - PPG Rate Mean: 69.2042634099686, RSP Rate Mean: 16.45797483465186
# Processing file: sub-RD105_ses-20180306_task-rest_run-201_echo-01_physio.tsv.gz
# 148: sub-RD105_ses-20180306_task-rest_run-201_echo-01_physio.tsv.gz - PPG Rate Mean: 71.63485459771343, RSP Rate Mean: 18.413141174277694
# Processing file: sub-RD103_ses-20180123_task-rest_run-001_echo-01_physio.tsv.gz
# 149: sub-RD103_ses-20180123_task-rest_run-001_echo-01_physio.tsv.gz - PPG Rate Mean: 48.556563011485686, RSP Rate Mean: 14.093996785662734
# Processing file: sub-RD103_ses-20180123_task-rest_run-201_echo-01_physio.tsv.gz
# 150: sub-RD103_ses-20180123_task-rest_run-201_echo-01_physio.tsv.gz - PPG Rate Mean: 60.99050678246693, RSP Rate Mean: 11.569275834331991
# Processing file: sub-RD103_ses-20180123_task-rest_run-101_echo-01_physio.tsv.gz
# 151: sub-RD103_ses-20180123_task-rest_run-101_echo-01_physio.tsv.gz - PPG Rate Mean: 53.903309979509, RSP Rate Mean: 9.749726791128941
# Processing file: sub-RD103_ses-20180130_task-rest_run-101_echo-01_physio.tsv.gz
# 152: sub-RD103_ses-20180130_task-rest_run-101_echo-01_physio.tsv.gz - PPG Rate Mean: 49.668046896328214, RSP Rate Mean: 12.876331331749116
# Processing file: sub-RD103_ses-20180130_task-rest_run-001_echo-01_physio.tsv.gz
# 153: sub-RD103_ses-20180130_task-rest_run-001_echo-01_physio.tsv.gz - PPG Rate Mean: 47.980953926679966, RSP Rate Mean: 11.900211791434819
# Processing file: sub-RD103_ses-20180130_task-rest_run-201_echo-01_physio.tsv.gz
# 154: sub-RD103_ses-20180130_task-rest_run-201_echo-01_physio.tsv.gz - PPG Rate Mean: 50.933414501035976, RSP Rate Mean: 12.298883267158915
# Processing file: sub-RD103_ses-20180130_task-rest_run-102_echo-01_physio.tsv.gz
# 155: sub-RD103_ses-20180130_task-rest_run-102_echo-01_physio.tsv.gz - PPG Rate Mean: 49.81466620957222, RSP Rate Mean: 12.633875034426206
# Processing file: sub-RD103_ses-20180306_task-rest_run-02_echo-01_physio.tsv.gz
# 156: sub-RD103_ses-20180306_task-rest_run-02_echo-01_physio.tsv.gz - PPG Rate Mean: 54.06139137278705, RSP Rate Mean: 15.235964847832888
# Processing file: sub-RD103_ses-20180102_task-rest_run-01_echo-01_physio.tsv.gz
# 157: sub-RD103_ses-20180102_task-rest_run-01_echo-01_physio.tsv.gz - PPG Rate Mean: 51.955460438105085, RSP Rate Mean: 14.430583557432822
# Processing file: sub-RD108_ses-20190326_task-rest_run-02_echo-01_physio.tsv.gz
# 158: sub-RD108_ses-20190326_task-rest_run-02_echo-01_physio.tsv.gz - PPG Rate Mean: 57.73497019587889, RSP Rate Mean: 16.053318637611575
# Processing file: sub-RD108_ses-20190312_task-rest_run-004_echo-01_physio.tsv.gz
# 159: sub-RD108_ses-20190312_task-rest_run-004_echo-01_physio.tsv.gz - PPG Rate Mean: 33.711539005968675, RSP Rate Mean: 15.623529157363992
# Processing file: sub-RD108_ses-20190312_task-rest_run-201_echo-01_physio.tsv.gz
# 160: sub-RD108_ses-20190312_task-rest_run-201_echo-01_physio.tsv.gz - PPG Rate Mean: 32.968762850176205, RSP Rate Mean: 15.308615037421317
# Processing file: sub-RD108_ses-20190312_task-rest_run-101_echo-01_physio.tsv.gz
# 161: sub-RD108_ses-20190312_task-rest_run-101_echo-01_physio.tsv.gz - PPG Rate Mean: 42.50974633475974, RSP Rate Mean: 11.607363218335816
# Processing file: sub-RD108_ses-20190319_task-rest_run-101_echo-01_physio.tsv.gz
# 162: sub-RD108_ses-20190319_task-rest_run-101_echo-01_physio.tsv.gz - PPG Rate Mean: 64.81679656578206, RSP Rate Mean: 8.33550088274679
# Processing file: sub-RD108_ses-20190319_task-rest_run-001_echo-01_physio.tsv.gz
# 163: sub-RD108_ses-20190319_task-rest_run-001_echo-01_physio.tsv.gz - PPG Rate Mean: 55.37849240002635, RSP Rate Mean: 15.77519370614831
# Processing file: sub-RD108_ses-20190319_task-rest_run-201_echo-01_physio.tsv.gz
# 164: sub-RD108_ses-20190319_task-rest_run-201_echo-01_physio.tsv.gz - PPG Rate Mean: 71.05624484192802, RSP Rate Mean: 15.67992176913503
# Processing file: sub-RD108_ses-20190219_task-rest_run-01_echo-01_physio.tsv.gz
# 165: sub-RD108_ses-20190219_task-rest_run-01_echo-01_physio.tsv.gz - PPG Rate Mean: 52.27724563458266, RSP Rate Mean: 17.336070010586962
# Processing file: sub-RD116_ses-20200114_task-rest_run-01_echo-01_physio.tsv.gz
# 166: sub-RD116_ses-20200114_task-rest_run-01_echo-01_physio.tsv.gz - PPG Rate Mean: 55.666038266376255, RSP Rate Mean: 14.273731473035056
# Processing file: sub-RD117_ses-20201006_task-rest_run-101_echo-01_physio.tsv.gz
# 167: sub-RD117_ses-20201006_task-rest_run-101_echo-01_physio.tsv.gz - PPG Rate Mean: 88.86341907174335, RSP Rate Mean: 6.826044086993603
# Processing file: sub-RD117_ses-20201006_task-rest_run-001_echo-01_physio.tsv.gz
# 168: sub-RD117_ses-20201006_task-rest_run-001_echo-01_physio.tsv.gz - PPG Rate Mean: 73.19336987203849, RSP Rate Mean: 6.590523029667203
# Processing file: sub-RD117_ses-20200921_task-rest_run-01_echo-01_physio.tsv.gz
# 169: sub-RD117_ses-20200921_task-rest_run-01_echo-01_physio.tsv.gz - PPG Rate Mean: 68.390009989031, RSP Rate Mean: 6.519115705399218
# Processing file: sub-RD117_ses-20201013_task-rest_run-01_echo-01_physio.tsv.gz
# 170: sub-RD117_ses-20201013_task-rest_run-01_echo-01_physio.tsv.gz - PPG Rate Mean: 70.98824209785663, RSP Rate Mean: 8.659201258768032
# Processing file: sub-RD118_ses-20210226_task-rest_run-01_echo-01_physio.tsv.gz
# 171: sub-RD118_ses-20210226_task-rest_run-01_echo-01_physio.tsv.gz - PPG Rate Mean: 68.0625036785466, RSP Rate Mean: 13.780971722099377
# Processing file: sub-RD118_ses-20210202_task-rest_run-01_echo-01_physio.tsv.gz
# 172: sub-RD118_ses-20210202_task-rest_run-01_echo-01_physio.tsv.gz - PPG Rate Mean: 72.08000990690228, RSP Rate Mean: 12.678395054900754
# Processing file: sub-RD104_ses-20180213_task-rest_run-102_echo-01_physio.tsv.gz
# 173: sub-RD104_ses-20180213_task-rest_run-102_echo-01_physio.tsv.gz - PPG Rate Mean: 74.78091673077911, RSP Rate Mean: 9.727598137691233
# Processing file: sub-RD104_ses-20180213_task-rest_run-001_echo-01_physio.tsv.gz
# 174: sub-RD104_ses-20180213_task-rest_run-001_echo-01_physio.tsv.gz - PPG Rate Mean: 71.55730728648223, RSP Rate Mean: 11.901005453406446
# Processing file: sub-RD104_ses-20180213_task-rest_run-201_echo-01_physio.tsv.gz
# 175: sub-RD104_ses-20180213_task-rest_run-201_echo-01_physio.tsv.gz - PPG Rate Mean: 78.99227430396354, RSP Rate Mean: 10.767515013967454
# Processing file: sub-RD104_ses-20180213_task-rest_run-101_echo-01_physio.tsv.gz
# 176: sub-RD104_ses-20180213_task-rest_run-101_echo-01_physio.tsv.gz - PPG Rate Mean: 70.25703146954442, RSP Rate Mean: 11.460174989165646
# Processing file: sub-RD104_ses-20180403_task-rest_run-02_echo-01_physio.tsv.gz
# 177: sub-RD104_ses-20180403_task-rest_run-02_echo-01_physio.tsv.gz - PPG Rate Mean: 65.50616668950327, RSP Rate Mean: 12.296995097362819
# Processing file: sub-RD104_ses-20180206_task-rest_run-001_echo-01_physio.tsv.gz
# 178: sub-RD104_ses-20180206_task-rest_run-001_echo-01_physio.tsv.gz - PPG Rate Mean: 73.53064328857772, RSP Rate Mean: 15.336871247632326
# Processing file: sub-RD104_ses-20180206_task-rest_run-101_echo-01_physio.tsv.gz
# 179: sub-RD104_ses-20180206_task-rest_run-101_echo-01_physio.tsv.gz - PPG Rate Mean: 74.32869263746815, RSP Rate Mean: 13.343989037862496
# Processing file: sub-RD104_ses-20180206_task-rest_run-102_echo-01_physio.tsv.gz
# 180: sub-RD104_ses-20180206_task-rest_run-102_echo-01_physio.tsv.gz - PPG Rate Mean: 74.33127814837613, RSP Rate Mean: 12.826564563133726
# Processing file: sub-RD104_ses-20180206_task-rest_run-201_echo-01_physio.tsv.gz
# 181: sub-RD104_ses-20180206_task-rest_run-201_echo-01_physio.tsv.gz - PPG Rate Mean: 74.99720505779825, RSP Rate Mean: 14.619228193411114
# Processing file: sub-RD104_ses-20180130_task-rest_run-01_echo-01_physio.tsv.gz
# 182: sub-RD104_ses-20180130_task-rest_run-01_echo-01_physio.tsv.gz - PPG Rate Mean: 77.12525151755243, RSP Rate Mean: 15.503591391028001
# Processing file: sub-RD106_ses-20180403_task-rest_run-001_echo-01_physio.tsv.gz
# 183: sub-RD106_ses-20180403_task-rest_run-001_echo-01_physio.tsv.gz - PPG Rate Mean: 72.62264479304224, RSP Rate Mean: 20.934054364879533
# Processing file: sub-RD106_ses-20180403_task-rest_run-101_echo-01_physio.tsv.gz
# 184: sub-RD106_ses-20180403_task-rest_run-101_echo-01_physio.tsv.gz - PPG Rate Mean: 86.2401498028128, RSP Rate Mean: 12.2324152866257
# Processing file: sub-RD106_ses-20180403_task-rest_run-201_echo-01_physio.tsv.gz
# 185: sub-RD106_ses-20180403_task-rest_run-201_echo-01_physio.tsv.gz - PPG Rate Mean: 80.1948820920616, RSP Rate Mean: 11.862843914274041
# Processing file: sub-RD106_ses-20180410_task-rest_run-001_echo-01_physio.tsv.gz
# 186: sub-RD106_ses-20180410_task-rest_run-001_echo-01_physio.tsv.gz - PPG Rate Mean: 64.10559867148092, RSP Rate Mean: 19.62886592868561
# Processing file: sub-RD106_ses-20180410_task-rest_run-201_echo-01_physio.tsv.gz
# 187: sub-RD106_ses-20180410_task-rest_run-201_echo-01_physio.tsv.gz - PPG Rate Mean: 115.80178943460636, RSP Rate Mean: 5.8687155904256505
# Processing file: sub-RD106_ses-20180410_task-rest_run-102_echo-01_physio.tsv.gz
# 188: sub-RD106_ses-20180410_task-rest_run-102_echo-01_physio.tsv.gz - PPG Rate Mean: 96.68308681267246, RSP Rate Mean: 5.944981684472136
# Processing file: sub-RD106_ses-20180410_task-rest_run-101_echo-01_physio.tsv.gz
# 189: sub-RD106_ses-20180410_task-rest_run-101_echo-01_physio.tsv.gz - PPG Rate Mean: 82.29692154785025, RSP Rate Mean: 6.668105967757146
# Processing file: sub-RD106_ses-20180529_task-rest_run-02_echo-01_physio.tsv.gz
# 190: sub-RD106_ses-20180529_task-rest_run-02_echo-01_physio.tsv.gz - PPG Rate Mean: 79.9713425880667, RSP Rate Mean: 96.50239815680138
# Processing file: sub-RD106_ses-20180706_task-rest_run-01_echo-01_physio.tsv.gz
# 191: sub-RD106_ses-20180706_task-rest_run-01_echo-01_physio.tsv.gz - PPG Rate Mean: 80.26280012373158, RSP Rate Mean: 19.481953632434696
# Processing file: sub-RD106_ses-20180327_task-rest_run-01_echo-01_physio.tsv.gz
# 192: sub-RD106_ses-20180327_task-rest_run-01_echo-01_physio.tsv.gz - PPG Rate Mean: 82.56250822878056, RSP Rate Mean: 20.500632810421283
# Processing file: sub-RD125_ses-20230404_task-rest_run-201_echo-01_physio.tsv.gz
# 193: sub-RD125_ses-20230404_task-rest_run-201_echo-01_physio.tsv.gz - PPG Rate Mean: 71.97421885779688, RSP Rate Mean: 8.592569666910087
# Processing file: sub-RD125_ses-20230404_task-rest_run-101_echo-01_physio.tsv.gz
# 194: sub-RD125_ses-20230404_task-rest_run-101_echo-01_physio.tsv.gz - PPG Rate Mean: 74.43909338736009, RSP Rate Mean: 8.402757996049965
# Processing file: sub-RD125_ses-20230404_task-rest_run-001_echo-01_physio.tsv.gz
# 195: sub-RD125_ses-20230404_task-rest_run-001_echo-01_physio.tsv.gz - PPG Rate Mean: 58.93632089555488, RSP Rate Mean: 14.481706629448443
# Processing file: sub-RD125_ses-20230407_task-rest_run-01_echo-01_physio.tsv.gz
# 196: sub-RD125_ses-20230407_task-rest_run-01_echo-01_physio.tsv.gz - PPG Rate Mean: 56.30488947448811, RSP Rate Mean: 12.507139795652547
# Processing file: sub-RD125_ses-20230328_task-rest_run-01_echo-01_physio.tsv.gz
# 197: sub-RD125_ses-20230328_task-rest_run-01_echo-01_physio.tsv.gz - PPG Rate Mean: 56.93502980075677, RSP Rate Mean: 17.96150238847461
# Processing file: sub-RD113_ses-20191001_task-rest_run-201_echo-01_physio.tsv.gz
# 198: sub-RD113_ses-20191001_task-rest_run-201_echo-01_physio.tsv.gz - PPG Rate Mean: 57.04728120073791, RSP Rate Mean: 15.338082090212637
# Processing file: sub-RD113_ses-20191001_task-rest_run-001_echo-01_physio.tsv.gz
# 199: sub-RD113_ses-20191001_task-rest_run-001_echo-01_physio.tsv.gz - PPG Rate Mean: 59.52623062694137, RSP Rate Mean: 8.555605479392364
# Processing file: sub-RD113_ses-20191001_task-rest_run-101_echo-01_physio.tsv.gz
# 200: sub-RD113_ses-20191001_task-rest_run-101_echo-01_physio.tsv.gz - PPG Rate Mean: 55.05905170221621, RSP Rate Mean: 17.053092010159453
# Processing file: sub-RD113_ses-20191119_task-rest_run-01_echo-01_physio.tsv.gz
# 201: sub-RD113_ses-20191119_task-rest_run-01_echo-01_physio.tsv.gz - PPG Rate Mean: 60.083843095298036, RSP Rate Mean: 15.10072814187173
# Processing file: sub-RD113_ses-20190924_task-rest_run-102_echo-01_physio.tsv.gz
# 202: sub-RD113_ses-20190924_task-rest_run-102_echo-01_physio.tsv.gz - PPG Rate Mean: 65.8588916745583, RSP Rate Mean: 12.295247792700513
# Processing file: sub-RD113_ses-20190924_task-rest_run-202_echo-01_physio.tsv.gz
# 203: sub-RD113_ses-20190924_task-rest_run-202_echo-01_physio.tsv.gz - PPG Rate Mean: 82.91064397094338, RSP Rate Mean: 17.896261481959876
# Processing file: sub-RD113_ses-20190924_task-rest_run-101_echo-01_physio.tsv.gz
# 204: sub-RD113_ses-20190924_task-rest_run-101_echo-01_physio.tsv.gz - Error: ('NeuroKit error: complexity_embedding(): dimension * delay should be lower than', ' the length of the signal.')
# Processing file: sub-RD113_ses-20190924_task-rest_run-001_echo-01_physio.tsv.gz
# /data/MoodGroup/code/miniconda3/envs/hrvanalysis/lib/python3.8/site-packages/neurokit2/signal/signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# /data/MoodGroup/code/miniconda3/envs/hrvanalysis/lib/python3.8/site-packages/neurokit2/rsp/rsp_symmetry.py:90: NeuroKitWarning: Not enough peaks and troughs (signal too short?) to compute symmetry, returning nan for symmetry.
#   warn(
# /data/MoodGroup/code/miniconda3/envs/hrvanalysis/lib/python3.8/site-packages/neurokit2/hrv/hrv_nonlinear.py:474: NeuroKitWarning: DFA_alpha2 related indices will not be calculated. The maximum duration of the windows provided for the long-term correlation is smaller than the minimum duration of windows. Refer to the `scale` argument in `nk.fractal_dfa()` for more information.
#   warn(
# /data/MoodGroup/code/miniconda3/envs/hrvanalysis/lib/python3.8/site-packages/neurokit2/rsp/rsp_intervalrelated.py:93: RuntimeWarning: Mean of empty slice
#   output["RSP_Rate_Mean"] = np.nanmean(data["RSP_Rate"].values)
# /data/MoodGroup/code/miniconda3/envs/hrvanalysis/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1664: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /data/MoodGroup/code/miniconda3/envs/hrvanalysis/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# 205: sub-RD113_ses-20190924_task-rest_run-001_echo-01_physio.tsv.gz - PPG Rate Mean: 66.84829263226901, RSP Rate Mean: 19.089480962537277
# Processing file: sub-RD113_ses-20190924_task-rest_run-201_echo-01_physio.tsv.gz
# 206: sub-RD113_ses-20190924_task-rest_run-201_echo-01_physio.tsv.gz - PPG Rate Mean: 74.73129183063232, RSP Rate Mean: 17.80506939612077
# Processing file: sub-RD113_ses-20190917_task-rest_run-01_echo-01_physio.tsv.gz
# 207: sub-RD113_ses-20190917_task-rest_run-01_echo-01_physio.tsv.gz - PPG Rate Mean: 59.549981069763035, RSP Rate Mean: 8.036664684678108
# Final DataFrame:
#          sub           ses       task      run     echo  srate  PPG_Rate_Mean  \
# 0  sub-RD120  ses-20210511  task-rest   run-01  echo-01  500.0      57.352980
# 1  sub-RD120  ses-20210518  task-rest  run-101  echo-01  500.0      58.260705
# 2  sub-RD120  ses-20210518  task-rest  run-001  echo-01  500.0      58.843313
# 3  sub-RD120  ses-20210518  task-rest  run-201  echo-01  500.0      58.896742
# 4  sub-RD120  ses-20210518  task-rest  run-102  echo-01  500.0      55.724787
#
#    HRV_MeanNN   HRV_SDNN  HRV_SDANN1  ...  RSP_Phase_Duration_Ratio  \
# 0  523.643757  62.233452   19.829023  ...                  0.434913
# 1  515.178771  52.564608   13.248358  ...                  0.522103
# 2  510.111349  56.470714    9.168709  ...                  0.461974
# 3  509.800647  61.975899   15.485916  ...                  0.529186
# 4  538.987486  69.016314   15.723710  ...                  0.460647
#
#    RRV_DFA_alpha1  RRV_MFDFA_alpha1_Width  RRV_MFDFA_alpha1_Peak  \
# 0             NaN                     NaN                    NaN
# 1             NaN                     NaN                    NaN
# 2             NaN                     NaN                    NaN
# 3             NaN                     NaN                    NaN
# 4             NaN                     NaN                    NaN
#
#    RRV_MFDFA_alpha1_Mean  RRV_MFDFA_alpha1_Max  RRV_MFDFA_alpha1_Delta  \
# 0                    NaN                   NaN                     NaN
# 1                    NaN                   NaN                     NaN
# 2                    NaN                   NaN                     NaN
# 3                    NaN                   NaN                     NaN
# 4                    NaN                   NaN                     NaN
#
#    RRV_MFDFA_alpha1_Asymmetry  RRV_MFDFA_alpha1_Fluctuation  \
# 0                         NaN                           NaN
# 1                         NaN                           NaN
# 2                         NaN                           NaN
# 3                         NaN                           NaN
# 4                         NaN                           NaN
#
#    RRV_MFDFA_alpha1_Increment
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
#
# [5 rows x 144 columns]
